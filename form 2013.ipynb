# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('try3.xlsx')
df=pd.DataFrame(data)
dfr=df.rename(columns=df.iloc[7])
df1=dfr[dfr['Ramakka.Y'].astype(str).str.isdigit()]
df2 = df1.dropna(how='all', axis=1)
df2
# Out:
#                              NaN  \
# 8                              1
# 9                              2
# 10                             3
# 11                             4
# 12                             5
# ..                           ...
# 249                          226
# 250                          227
# 251  TOTAL VOTES ON EVM MACHINES
# 252                          228
# 253                          ALL
#
#                                               NaN P. Thangaraj K.R. Devaraja  \
# 8                                          146001            3             0
# 9                                          146002            2             1
# 10                                         146003            2             2
# 11                                         146004            4             5
# 12                                         146005            3             1
# ..                                            ...          ...           ...
# ...

# %%
su = df2.rename(columns={df2.columns[1]: 'Polling Station'})
su
# Out:
#                  Polling Station  \
# 8                              1
# 9                              2
# 10                             3
# 11                             4
# 12                             5
# ..                           ...
# 249                          226
# 250                          227
# 251  TOTAL VOTES ON EVM MACHINES
# 252                          228
# 253                          ALL
#
#                                   Polling Station P. Thangaraj K.R. Devaraja  \
# 8                                          146001            3             0
# 9                                          146002            2             1
# 10                                         146003            2             2
# 11                                         146004            4             5
# 12                                         146005            3             1
# ..                                            ...          ...           ...
# ...

# %%
df_final=df2[df2['NaN'].astype(str).str.isdigit()]
df_final
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
df2 = df1.dropna(how='all', axis=1)
df2
# Out:
#     ANNEXURE XLI Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 8              1     146001          3          0        148        186
# 9              2     146002          2          1        122        249
# 10             3     146003          2          2        100        269
# 11             4     146004          4          5         51        419
# 12             5     146005          3          1         83        388
# ..           ...        ...        ...        ...        ...        ...
# 246          223     146223          2          2        111        252
# 247          224     146224          1          0        103        281
# 248          225     146225          0          0        152        201
# 249          226     146226          0          1        157        306
# 250          227     146227          4          4        211        282
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 17 Unnamed: 18  \
# ...

# %%
df.rename(columns=df.iloc[0])
